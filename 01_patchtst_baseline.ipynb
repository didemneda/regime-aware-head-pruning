# %% [markdown]
# <a href="https://colab.research.google.com/github/didemneda/regime-aware-head-pruning/blob/didem%2Fpatchtst-baseline/01_patchtst_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content

# !git clone -b didem/patchtst-baseline \
https://github.com/didemneda/regime-aware-head-pruning.git

# %cd /content/regime-aware-head-pruning
# !git status
# !git branch
# !ls
# Out:
# /content
# Cloning into 'regime-aware-head-pruning'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: '/content/regime-aware-head-pruning'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# sample_data

# %%
# %cd /content

# !rm -rf Time-Series-Library
# !git clone https://github.com/thuml/Time-Series-Library.git
# Out:
# /content
# Cloning into 'Time-Series-Library'...
# remote: Enumerating objects: 2295, done.
# remote: Total 2295 (delta 0), reused 0 (delta 0), pack-reused 2295 (from 1)
# Receiving objects: 100% (2295/2295), 78.43 MiB | 30.43 MiB/s, done.
# Resolving deltas: 100% (1570/1570), done.

# %%
# %cd /content/Time-Series-Library
# !ls
# Out:
# /content/Time-Series-Library
# CONTRIBUTING.md     Dockerfile	LICENSE  README.md	   run.py    utils
# data_provider	    exp		models	 README_zh.md	   scripts
# docker-compose.yml  layers	pic	 requirements.txt  tutorial

# %%
# %cd /content/Time-Series-Library

# !pip install -q -r requirements.txt
# !pip install -q statsmodels scipy scikit-learn matplotlib pyyaml thop
# Out:
# /content/Time-Series-Library
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.6 MB/s eta 0:00:00
# ERROR: Ignored the following versions that require a different python version: 0.0.11 Requires-Python <3.11,>=3.10; 0.0.12 Requires-Python <3.11,>=3.10; 0.1.1 Requires-Python <3.11,>=3.10; 0.1.14 Requires-Python <3.11,>=3.10; 0.1.15 Requires-Python <3.11,>=3.10; 0.1.16 Requires-Python <3.11,>=3.10; 0.1.17 Requires-Python <3.11,>=3.10; 0.1.18 Requires-Python <3.11,>=3.10; 0.1.2 Requires-Python <3.11,>=3.10; 0.1.21 Requires-Python <3.11,>=3.10; 0.1.22 Requires-Python <3.11,>=3.10; 0.1.23 Requires-Python <3.11,>=3.10; 0.1.24 Requires-Python <3.11,>=3.10; 0.1.25 Requires-Python <3.11,>=3.10; 0.1.3 Requires-Python <3.11,>=3.10; 0.1.31 Requires-Python <3.11,>=3.10; 0.1.32 Requires-Python <3.11,>=3.10; 0.1.4 Requires-Python <3.11,>=3.10; 0.1.5 Requires-Python <3.11,>=3.10; 0.1.6 Requires-Python <3.11,>=3.10; 0.1.7 Requires-Python <3.11,>=3.10; 0.10.0 Requires-Python >=3.7,<3.10; 0.10.1 Requires-Python >=3.7,<3.10; 0.11.0 Requires-Python >=3.7,<3.10; 0.11.1 Requires-Python >=3.7,<3.10; 0.11.2 Requires-Python >=3.7,<3.10; 0.11.3 Requires-Python >=3.7,<3.10; 0.11.4 Requires-Python >=3.7,<3.10; 0.12.0 Requires-Python >=3.7,<3.10; 0.12.1 Requires-Python >=3.7,<3.10; 0.13.0 Requires-Python >=3.7,<3.11; 0.13.1 Requires-Python >=3.7,<3.11; 0.13.2 Requires-Python >=3.7,<3.11; 0.13.3 Requires-Python >=3.7,<3.11; 0.13.4 Requires-Python >=3.7,<3.11; 0.14.0 Requires-Python >=3.7,<3.11; 0.14.1 Requires-Python <3.11,>=3.7; 0.15.0 Requires-Python <3.11,>=3.7; 0.15.1 Requires-Python <3.11,>=3.7; 0.16.0 Requires-Python <3.11,>=3.7; 0.16.1 Requires-Python <3.12,>=3.7; 0.17.0 Requires-Python <3.12,>=3.7; 0.17.1 Requires-Python <3.12,>=3.7; 0.17.2 Requires-Python <3.12,>=3.7; 0.18.0 Requires-Python <3.12,>=3.7; 0.18.1 Requires-Python <3.12,>=3.7; 0.19.0 Requires-Python <3.12,>=3.7; 0.19.1 Requires-Python <3.12,>=3.7; 0.19.2 Requires-Python <3.12,>=3.7; 0.20.0 Requires-Python <3.12,>=3.8; 0.20.1 Requires-Python <3.12,>=3.8; 0.21.0 Requires-Python <3.12,>=3.8; 0.21.1 Requires-Python <3.12,>=3.8; 0.22.0 Requires-Python <3.12,>=3.8; 0.22.1 Requires-Python <3.12,>=3.8; 0.23.0 Requires-Python <3.12,>=3.8; 0.23.1 Requires-Python <3.12,>=3.8; 1.0.1 Requires-Python <3.11,>=3.10; 1.1.0 Requires-Python <3.11,>=3.10; 1.2.0 Requires-Python <3.12,>=3.10; 1.2.1 Requires-Python <3.12,>=3.10; 1.2.2 Requires-Python <3.12,>=3.10; 1.2.3 Requires-Python <3.12,>=3.10; 1.2.4 Requires-Python <3.12,>=3.10; 1.2.5 Requires-Python <3.12,>=3.10; 1.2.6 Requires-Python <3.12,>=3.10; 1.2.7 Requires-Python <3.12,>=3.10; 1.2.8 Requires-Python <3.12,>=3.10; 1.2.9 Requires-Python <3.12,>=3.10; 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11; 1.3.0 Requires-Python <3.12,>=3.10
# ERROR: Could not find a version that satisfies the requirement timesfm==1.3.0 (from versions: 1.0.0, 2.0.0, 2.0.1, 2.0.2)
# ERROR: No matching distribution found for timesfm==1.3.0

# %%
import torch
import pandas as pd
import numpy as np

print("Torch:", torch.__version__)
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Torch: 2.11.0+cu128
# GPU: Tesla T4

# %%
# %cd /content/Time-Series-Library

# !mkdir -p dataset
# !rm -rf dataset/ETDataset
# !git clone https://github.com/zhouhaoyi/ETDataset.git dataset/ETDataset
# Out:
# /content/Time-Series-Library
# Cloning into 'dataset/ETDataset'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 187 (delta 26), reused 20 (delta 20), pack-reused 157 (from 1)
# Receiving objects: 100% (187/187), 3.86 MiB | 8.40 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
from pathlib import Path

data_path = Path(
    "/content/Time-Series-Library/dataset/ETDataset/ETT-small/ETTh1.csv"
)

print("Dosya var mı:", data_path.exists())
print(data_path)
# Out:
# Dosya var mı: True
# /content/Time-Series-Library/dataset/ETDataset/ETT-small/ETTh1.csv

# %%
import pandas as pd

df = pd.read_csv(data_path)

print("Boyut:", df.shape)
display(df.head())

print("Kolonlar:", df.columns.tolist())
print("Eksik değer sayıları:")
print(df.isna().sum())
# Out:
# Boyut: (17420, 8)
#                   date   HUFL   HULL   MUFL   MULL   LUFL   LULL         OT
# 0  2016-07-01 00:00:00  5.827  2.009  1.599  0.462  4.203  1.340  30.531000
# 1  2016-07-01 01:00:00  5.693  2.076  1.492  0.426  4.142  1.371  27.787001
# 2  2016-07-01 02:00:00  5.157  1.741  1.279  0.355  3.777  1.218  27.787001
# 3  2016-07-01 03:00:00  5.090  1.942  1.279  0.391  3.807  1.279  25.044001
# 4  2016-07-01 04:00:00  5.358  1.942  1.492  0.462  3.868  1.279  21.948000
# Kolonlar: ['date', 'HUFL', 'HULL', 'MUFL', 'MULL', 'LUFL', 'LULL', 'OT']
# Eksik değer sayıları:
# date    0
# HUFL    0
# HULL    0
# MUFL    0
# MULL    0
# LUFL    0
# LULL    0
# OT      0
# dtype: int64

# %%
# !pip install -q --no-deps einops
# !pip install -q --no-deps patool
# !pip install -q --no-deps thop
# !pip install -q --no-deps sktime
# !pip install -q reformer-pytorch
# !pip install -q --no-deps scikit-base
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.4/101.4 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 45.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.3/165.3 kB 6.8 MB/s eta 0:00:00

# %%
import torch
import numpy as np
import pandas as pd
import scipy
import sklearn
import statsmodels
import einops
import patoolib



from models import PatchTST

print("PatchTST import başarılı.")
print("Torch:", torch.__version__)
print("CUDA:", torch.cuda.is_available())
# Out:
# PatchTST import başarılı.
# Torch: 2.11.0+cu128
# CUDA: True

# %%
# %cd /content/Time-Series-Library

# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/ETDataset/ETT-small/ \
  --data_path ETTh1.csv \
  --model_id ETTh1_336_96_baseline \
  --model PatchTST \
  --data ETTh1 \
  --features M \
  --seq_len 336 \
  --label_len 48 \
  --pred_len 96 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --e_layers 3 \
  --d_layers 1 \
  --factor 3 \
  --d_model 128 \
  --d_ff 256 \
  --n_heads 4 \
  --batch_size 32 \
  --train_epochs 10 \
  --patience 3 \
  --learning_rate 0.0001 \
  --des baseline \
  --itr 1
# Out:
# /content/Time-Series-Library
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh1_336_96_baselineModel:              PatchTST
#
# Data Loader
#   Data:               ETTh1               Root Path:          ./dataset/ETDataset/ETT-small/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            336                 Label Len:          48
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            128
#   n heads:            4                   e layers:           3
#   d layers:           1                   d FF:               256
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       10                  Batch Size:         32
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                baseline            Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: PatchTST ...
# >>>>>>>start training : long_term_forecast_ETTh1_336_96_baseline_PatchTST_ETTh1_ftM_sl336_ll48_pl96_dm128_nh4_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.4306515
# 	speed: 0.0848s/iter; left time: 209.5921s
# 	iters: 200, epoch: 1 | loss: 0.4137464
# 	speed: 0.0221s/iter; left time: 52.4414s
# Epoch: 1 cost time: 7.522028923034668
# Epoch: 1, Steps: 257 | Train Loss: 0.4214262 Vali Loss: 0.7315391 Test Loss: 0.3968202
# Validation loss decreased (inf --> 0.731539).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3947957
# 	speed: 0.0636s/iter; left time: 140.9068s
# 	iters: 200, epoch: 2 | loss: 0.3446186
# 	speed: 0.0202s/iter; left time: 42.6343s
# Epoch: 2 cost time: 5.539890766143799
# Epoch: 2, Steps: 257 | Train Loss: 0.3796835 Vali Loss: 0.7161588 Test Loss: 0.3938735
# Validation loss decreased (0.731539 --> 0.716159).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.3837466
# 	speed: 0.0694s/iter; left time: 135.8000s
# 	iters: 200, epoch: 3 | loss: 0.3717185
# 	speed: 0.0203s/iter; left time: 37.7213s
# Epoch: 3 cost time: 6.57423210144043
# Epoch: 3, Steps: 257 | Train Loss: 0.3629771 Vali Loss: 0.6883598 Test Loss: 0.3777352
# Validation loss decreased (0.716159 --> 0.688360).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.3196180
# 	speed: 0.0592s/iter; left time: 100.6798s
# 	iters: 200, epoch: 4 | loss: 0.3352404
# 	speed: 0.0213s/iter; left time: 34.0350s
# Epoch: 4 cost time: 6.201516389846802
# Epoch: 4, Steps: 257 | Train Loss: 0.3559668 Vali Loss: 0.6817115 Test Loss: 0.3779413
# Validation loss decreased (0.688360 --> 0.681711).  Saving model ...
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.2933395
# 	speed: 0.0667s/iter; left time: 96.2763s
# 	iters: 200, epoch: 5 | loss: 0.3018072
# 	speed: 0.0206s/iter; left time: 27.6380s
# Epoch: 5 cost time: 5.6987144947052
# Epoch: 5, Steps: 257 | Train Loss: 0.3517192 Vali Loss: 0.6810274 Test Loss: 0.3762230
# Validation loss decreased (0.681711 --> 0.681027).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.3255947
# 	speed: 0.0651s/iter; left time: 77.2075s
# 	iters: 200, epoch: 6 | loss: 0.4565916
# 	speed: 0.0207s/iter; left time: 22.4515s
# Epoch: 6 cost time: 5.987333536148071
# Epoch: 6, Steps: 257 | Train Loss: 0.3502240 Vali Loss: 0.6774843 Test Loss: 0.3747531
# Validation loss decreased (0.681027 --> 0.677484).  Saving model ...
# Updating learning rate to 3.125e-06
# 	iters: 100, epoch: 7 | loss: 0.3713040
# 	speed: 0.0599s/iter; left time: 55.6847s
# 	iters: 200, epoch: 7 | loss: 0.3498179
# 	speed: 0.0215s/iter; left time: 17.8599s
# Epoch: 7 cost time: 5.892565965652466
# Epoch: 7, Steps: 257 | Train Loss: 0.3489504 Vali Loss: 0.6731616 Test Loss: 0.3747510
# Validation loss decreased (0.677484 --> 0.673162).  Saving model ...
# Updating learning rate to 1.5625e-06
# 	iters: 100, epoch: 8 | loss: 0.3473183
# 	speed: 0.0615s/iter; left time: 41.3026s
# 	iters: 200, epoch: 8 | loss: 0.3178993
# 	speed: 0.0211s/iter; left time: 12.0472s
# Epoch: 8 cost time: 5.738759279251099
# Epoch: 8, Steps: 257 | Train Loss: 0.3489114 Vali Loss: 0.6734234 Test Loss: 0.3746105
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 7.8125e-07
# 	iters: 100, epoch: 9 | loss: 0.3054121
# 	speed: 0.0652s/iter; left time: 27.0668s
# 	iters: 200, epoch: 9 | loss: 0.3532647
# 	speed: 0.0211s/iter; left time: 6.6470s
# Epoch: 9 cost time: 6.085765838623047
# Epoch: 9, Steps: 257 | Train Loss: 0.3483759 Vali Loss: 0.6771917 Test Loss: 0.3744911
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.90625e-07
# 	iters: 100, epoch: 10 | loss: 0.3325130
# 	speed: 0.0603s/iter; left time: 9.5265s
# 	iters: 200, epoch: 10 | loss: 0.3522374
# 	speed: 0.0218s/iter; left time: 1.2621s
# Epoch: 10 cost time: 5.985803842544556
# Epoch: 10, Steps: 257 | Train Loss: 0.3483089 Vali Loss: 0.6821511 Test Loss: 0.3745665
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : long_term_forecast_ETTh1_336_96_baseline_PatchTST_ETTh1_ftM_sl336_ll48_pl96_dm128_nh4_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (2785, 96, 7) (2785, 96, 7)
# test shape: (2785, 96, 7) (2785, 96, 7)
# mse:0.37387582659721375, mae:0.39887988567352295, dtw:Not calculated

# %%
# !find /content/Time-Series-Library/checkpoints -type f
# Out:
# /content/Time-Series-Library/checkpoints/long_term_forecast_ETTh1_336_96_baseline_PatchTST_ETTh1_ftM_sl336_ll48_pl96_dm128_nh4_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_0/checkpoint.pth

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

PROJECT_DIR = Path(
    "/content/drive/MyDrive/BIL401_Regime_Head_Pruning"
)

SCRIPT_DIR = PROJECT_DIR / "scripts"
RESULT_DIR = PROJECT_DIR / "results"
CHECKPOINT_DIR = PROJECT_DIR / "checkpoints"
CONFIG_DIR = PROJECT_DIR / "configs"

for directory in [
    SCRIPT_DIR,
    RESULT_DIR,
    CHECKPOINT_DIR,
    CONFIG_DIR,
]:
    directory.mkdir(parents=True, exist_ok=True)

print("Proje klasörü:", PROJECT_DIR)
# Out:
# Proje klasörü: /content/drive/MyDrive/BIL401_Regime_Head_Pruning

# %%
baseline_script = r"""#!/bin/bash

cd /content/Time-Series-Library

python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/ETDataset/ETT-small/ \
  --data_path ETTh1.csv \
  --model_id ETTh1_336_96_baseline \
  --model PatchTST \
  --data ETTh1 \
  --features M \
  --seq_len 336 \
  --label_len 48 \
  --pred_len 96 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --e_layers 3 \
  --d_layers 1 \
  --factor 3 \
  --d_model 128 \
  --d_ff 256 \
  --n_heads 4 \
  --batch_size 32 \
  --train_epochs 10 \
  --patience 3 \
  --learning_rate 0.0001 \
  --des baseline \
  --itr 1
"""

script_path = SCRIPT_DIR / "run_b0_patchtst_etth1.sh"
script_path.write_text(baseline_script, encoding="utf-8")

print("Komut kaydedildi:")
print(script_path)
# Out:
# Komut kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/scripts/run_b0_patchtst_etth1.sh

# %%
from pathlib import Path

checkpoint_root = Path(
    "/content/Time-Series-Library/checkpoints"
)

baseline_checkpoints = [
    path
    for path in checkpoint_root.iterdir()
    if "ETTh1_336_96_baseline" in path.name
]

print("Bulunan checkpoint klasörleri:")

for path in baseline_checkpoints:
    print(path)
# Out:
# Bulunan checkpoint klasörleri:
# /content/Time-Series-Library/checkpoints/long_term_forecast_ETTh1_336_96_baseline_PatchTST_ETTh1_ftM_sl336_ll48_pl96_dm128_nh4_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_0

# %%
import shutil

if len(baseline_checkpoints) != 1:
    raise RuntimeError(
        f"1 checkpoint bekleniyordu, "
        f"{len(baseline_checkpoints)} bulundu."
    )

source_checkpoint = baseline_checkpoints[0]

target_checkpoint = (
    CHECKPOINT_DIR
    / "B0_patchtst_etth1_336_dm128_h4"
)

if target_checkpoint.exists():
    shutil.rmtree(target_checkpoint)

shutil.copytree(
    source_checkpoint,
    target_checkpoint,
)

print("Checkpoint kaydedildi:")
print(target_checkpoint)
# Out:
# Checkpoint kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/checkpoints/B0_patchtst_etth1_336_dm128_h4

# %%
for path in target_checkpoint.rglob("*"):
    print(path)
# Out:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/checkpoints/B0_patchtst_etth1_336_dm128_h4/checkpoint.pth

# %%
import pandas as pd
from pathlib import Path

PROJECT_DIR = Path(
    "/content/drive/MyDrive/BIL401_Regime_Head_Pruning"
)

RESULT_DIR = PROJECT_DIR / "results"
RESULT_DIR.mkdir(parents=True, exist_ok=True)

baseline_result = {
    "experiment_id": "B0_patchtst_etth1_336_dm128_h4",
    "model": "PatchTST",
    "dataset": "ETTh1",
    "seq_len": 336,
    "label_len": 48,
    "pred_len": 96,
    "d_model": 128,
    "d_ff": 256,
    "n_heads": 4,
    "e_layers": 3,
    "batch_size": 32,
    "max_epochs": 10,
    "best_epoch": 7,
    "patience": 3,
    "learning_rate": 0.0001,
    "best_val_loss": 0.6731616,
    "test_mse": 0.37387582659721375,
    "test_mae": 0.39887988567352295,
    "status": "completed",
}

results_path = RESULT_DIR / "baseline_experiments.csv"

if results_path.exists():
    results_df = pd.read_csv(results_path)
else:
    results_df = pd.DataFrame()

results_df = pd.concat(
    [
        results_df,
        pd.DataFrame([baseline_result]),
    ],
    ignore_index=True,
)

results_df = results_df.drop_duplicates(
    subset=["experiment_id"],
    keep="last",
)

results_df.to_csv(
    results_path,
    index=False,
)

display(results_df)

print("Sonuçlar kaydedildi:")
print(results_path)
# Out:
#                     experiment_id     model dataset  seq_len  label_len  \
# 0  B0_patchtst_etth1_336_dm128_h4  PatchTST   ETTh1      336         48
#
#    pred_len  d_model  d_ff  n_heads  e_layers  batch_size  max_epochs  \
# 0        96      128   256        4         3          32          10
#
#    best_epoch  patience  learning_rate  best_val_loss  test_mse  test_mae  \
# 0           7         3         0.0001       0.673162  0.373876   0.39888
#
#       status
# 0  completed
# Sonuçlar kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/results/baseline_experiments.csv

# %%
from pathlib import Path

PROJECT_DIR = Path(
    "/content/drive/MyDrive/BIL401_Regime_Head_Pruning"
)

CONFIG_DIR = PROJECT_DIR / "configs"
CONFIG_DIR.mkdir(parents=True, exist_ok=True)

baseline_config = """
experiment_id: B0_patchtst_etth1_336_dm128_h4

model:
  name: PatchTST
  d_model: 128
  d_ff: 256
  n_heads: 4
  e_layers: 3
  d_layers: 1
  factor: 3
  dropout: 0.1

data:
  name: ETTh1
  root_path: ./dataset/ETDataset/ETT-small/
  data_path: ETTh1.csv
  features: M
  target: OT
  freq: h
  seq_len: 336
  label_len: 48
  pred_len: 96
  enc_in: 7
  dec_in: 7
  c_out: 7

training:
  batch_size: 32
  max_epochs: 10
  best_epoch: 7
  patience: 3
  learning_rate: 0.0001
  loss: MSE
  lradj: type1
  optimizer: Adam
  use_gpu: true

results:
  best_val_loss: 0.6731616
  test_mse: 0.37387582659721375
  test_mae: 0.39887988567352295

notes:
  description: baseline
  checkpoint_selected_by: validation_loss
""".strip()

config_path = (
    CONFIG_DIR
    / "B0_patchtst_etth1_336_dm128_h4.yaml"
)

config_path.write_text(
    baseline_config,
    encoding="utf-8",
)

print("Config kaydedildi:")
print(config_path)
# Out:
# Config kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/configs/B0_patchtst_etth1_336_dm128_h4.yaml

# %%
print("CSV içeriği:")
display(pd.read_csv(results_path))

print("\nConfig içeriği:")
print(config_path.read_text(encoding="utf-8"))
# Out:
# CSV içeriği:
#                     experiment_id     model dataset  seq_len  label_len  \
# 0  B0_patchtst_etth1_336_dm128_h4  PatchTST   ETTh1      336         48
#
#    pred_len  d_model  d_ff  n_heads  e_layers  batch_size  max_epochs  \
# 0        96      128   256        4         3          32          10
#
#    best_epoch  patience  learning_rate  best_val_loss  test_mse  test_mae  \
# 0           7         3         0.0001       0.673162  0.373876   0.39888
#
#       status
# 0  completed
# Config içeriği:
# experiment_id: B0_patchtst_etth1_336_dm128_h4
#
# model:
#   name: PatchTST
#   d_model: 128
#   d_ff: 256
#   n_heads: 4
#   e_layers: 3
#   d_layers: 1
#   factor: 3
#   dropout: 0.1
#
# data:
#   name: ETTh1
#   root_path: ./dataset/ETDataset/ETT-small/
#   data_path: ETTh1.csv
#   features: M
#   target: OT
#   freq: h
#   seq_len: 336
#   label_len: 48
#   pred_len: 96
#   enc_in: 7
#   dec_in: 7
#   c_out: 7
#
# training:
#   batch_size: 32
#   max_epochs: 10
#   best_epoch: 7
#   patience: 3
#   learning_rate: 0.0001
#   loss: MSE
#   lradj: type1
#   optimizer: Adam
#   use_gpu: true
#
# results:
#   best_val_loss: 0.6731616
#   test_mse: 0.37387582659721375
#   test_mae: 0.39887988567352295
#
# notes:
#   description: baseline
#   checkpoint_selected_by: validation_loss

# %%
# %cd /content/Time-Series-Library

# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/ETDataset/ETT-small/ \
  --data_path ETTh1.csv \
  --model_id ETTh1_512_96_dm128_h16 \
  --model PatchTST \
  --data ETTh1 \
  --features M \
  --seq_len 512 \
  --label_len 48 \
  --pred_len 96 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --e_layers 3 \
  --d_layers 1 \
  --factor 3 \
  --d_model 128 \
  --d_ff 256 \
  --n_heads 16 \
  --batch_size 32 \
  --train_epochs 20 \
  --patience 5 \
  --learning_rate 0.0001 \
  --des baseline_b1 \
  --itr 1
# Out:
# /content/Time-Series-Library
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh1_512_96_dm128_h16Model:              PatchTST
#
# Data Loader
#   Data:               ETTh1               Root Path:          ./dataset/ETDataset/ETT-small/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          48
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            128
#   n heads:            16                  e layers:           3
#   d layers:           1                   d FF:               256
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       20                  Batch Size:         32
#   Patience:           5                   Learning Rate:      0.0001
#   Des:                baseline_b1         Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: PatchTST ...
# >>>>>>>start training : long_term_forecast_ETTh1_512_96_dm128_h16_PatchTST_ETTh1_ftM_sl512_ll48_pl96_dm128_nh16_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8033
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.4667231
# 	speed: 0.0619s/iter; left time: 305.7641s
# 	iters: 200, epoch: 1 | loss: 0.3509181
# 	speed: 0.0429s/iter; left time: 207.7024s
# Epoch: 1 cost time: 11.543367147445679
# Epoch: 1, Steps: 252 | Train Loss: 0.4300319 Vali Loss: 0.7573439 Test Loss: 0.3987957
# Validation loss decreased (inf --> 0.757344).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.4080897
# 	speed: 0.1042s/iter; left time: 488.4433s
# 	iters: 200, epoch: 2 | loss: 0.3910504
# 	speed: 0.0433s/iter; left time: 198.6737s
# Epoch: 2 cost time: 11.218527793884277
# Epoch: 2, Steps: 252 | Train Loss: 0.3838082 Vali Loss: 0.7389789 Test Loss: 0.3936101
# Validation loss decreased (0.757344 --> 0.738979).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.3568471
# 	speed: 0.1044s/iter; left time: 463.1667s
# 	iters: 200, epoch: 3 | loss: 0.3587312
# 	speed: 0.0438s/iter; left time: 189.8713s
# Epoch: 3 cost time: 11.323221206665039
# Epoch: 3, Steps: 252 | Train Loss: 0.3603303 Vali Loss: 0.7859217 Test Loss: 0.3860128
# EarlyStopping counter: 1 out of 5
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.3586521
# 	speed: 0.1047s/iter; left time: 437.9866s
# 	iters: 200, epoch: 4 | loss: 0.3285234
# 	speed: 0.0442s/iter; left time: 180.4735s
# Epoch: 4 cost time: 11.387367248535156
# Epoch: 4, Steps: 252 | Train Loss: 0.3502572 Vali Loss: 0.7587916 Test Loss: 0.3789293
# EarlyStopping counter: 2 out of 5
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.3349445
# 	speed: 0.1059s/iter; left time: 416.4481s
# 	iters: 200, epoch: 5 | loss: 0.3635092
# 	speed: 0.0446s/iter; left time: 171.1129s
# Epoch: 5 cost time: 11.525278806686401
# Epoch: 5, Steps: 252 | Train Loss: 0.3445756 Vali Loss: 0.7595257 Test Loss: 0.3774536
# EarlyStopping counter: 3 out of 5
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.3481042
# 	speed: 0.1069s/iter; left time: 393.4805s
# 	iters: 200, epoch: 6 | loss: 0.3090178
# 	speed: 0.0450s/iter; left time: 160.9818s
# Epoch: 6 cost time: 11.621210098266602
# Epoch: 6, Steps: 252 | Train Loss: 0.3419508 Vali Loss: 0.7382330 Test Loss: 0.3776003
# Validation loss decreased (0.738979 --> 0.738233).  Saving model ...
# Updating learning rate to 3.125e-06
# 	iters: 100, epoch: 7 | loss: 0.2999752
# 	speed: 0.1085s/iter; left time: 372.0209s
# 	iters: 200, epoch: 7 | loss: 0.3372696
# 	speed: 0.0456s/iter; left time: 151.8938s
# Epoch: 7 cost time: 11.824787855148315
# Epoch: 7, Steps: 252 | Train Loss: 0.3405674 Vali Loss: 0.7459205 Test Loss: 0.3771809
# EarlyStopping counter: 1 out of 5
# Updating learning rate to 1.5625e-06
# 	iters: 100, epoch: 8 | loss: 0.3620041
# 	speed: 0.1109s/iter; left time: 352.3324s
# 	iters: 200, epoch: 8 | loss: 0.4101428
# 	speed: 0.0460s/iter; left time: 141.6907s
# Epoch: 8 cost time: 12.06942081451416
# Epoch: 8, Steps: 252 | Train Loss: 0.3406739 Vali Loss: 0.7388640 Test Loss: 0.3771536
# EarlyStopping counter: 2 out of 5
# Updating learning rate to 7.8125e-07
# 	iters: 100, epoch: 9 | loss: 0.3320622
# 	speed: 0.1165s/iter; left time: 340.7108s
# 	iters: 200, epoch: 9 | loss: 0.3163607
# 	speed: 0.0466s/iter; left time: 131.6271s
# Epoch: 9 cost time: 12.310659408569336
# Epoch: 9, Steps: 252 | Train Loss: 0.3397966 Vali Loss: 0.7408104 Test Loss: 0.3770555
# EarlyStopping counter: 3 out of 5
# Updating learning rate to 3.90625e-07
# 	iters: 100, epoch: 10 | loss: 0.3181913
# 	speed: 0.1175s/iter; left time: 314.0064s
# 	iters: 200, epoch: 10 | loss: 0.3181522
# 	speed: 0.0464s/iter; left time: 119.3609s
# Epoch: 10 cost time: 12.081001281738281
# Epoch: 10, Steps: 252 | Train Loss: 0.3396195 Vali Loss: 0.7447575 Test Loss: 0.3771019
# EarlyStopping counter: 4 out of 5
# Updating learning rate to 1.953125e-07
# 	iters: 100, epoch: 11 | loss: 0.3977166
# 	speed: 0.1131s/iter; left time: 273.8350s
# 	iters: 200, epoch: 11 | loss: 0.3315838
# 	speed: 0.0461s/iter; left time: 107.0342s
# Epoch: 11 cost time: 11.949180841445923
# Epoch: 11, Steps: 252 | Train Loss: 0.3395864 Vali Loss: 0.7395977 Test Loss: 0.3773011
# EarlyStopping counter: 5 out of 5
# Early stopping
# >>>>>>>testing : long_term_forecast_ETTh1_512_96_dm128_h16_PatchTST_ETTh1_ftM_sl512_ll48_pl96_dm128_nh16_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b1_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (2785, 96, 7) (2785, 96, 7)
# test shape: (2785, 96, 7) (2785, 96, 7)
# mse:0.37642401456832886, mae:0.40531596541404724, dtw:Not calculated

# %%
import pandas as pd
from pathlib import Path

PROJECT_DIR = Path(
    "/content/drive/MyDrive/BIL401_Regime_Head_Pruning"
)

RESULT_DIR = PROJECT_DIR / "results"
RESULT_DIR.mkdir(parents=True, exist_ok=True)

results_path = RESULT_DIR / "baseline_experiments.csv"

b1_result = {
    "experiment_id": "B1_patchtst_etth1_512_dm128_h16",
    "model": "PatchTST",
    "dataset": "ETTh1",
    "seq_len": 512,
    "label_len": 48,
    "pred_len": 96,
    "d_model": 128,
    "d_ff": 256,
    "n_heads": 16,
    "e_layers": 3,
    "batch_size": 32,
    "max_epochs": 20,
    "best_epoch": 6,
    "patience": 5,
    "learning_rate": 0.0001,
    "best_val_loss": 0.7382330,
    "test_mse": 0.37642401456832886,
    "test_mae": 0.40531596541404724,
    "status": "completed",
}

if results_path.exists():
    results_df = pd.read_csv(results_path)
else:
    results_df = pd.DataFrame()

results_df = pd.concat(
    [results_df, pd.DataFrame([b1_result])],
    ignore_index=True,
)

results_df = results_df.drop_duplicates(
    subset=["experiment_id"],
    keep="last",
)

results_df.to_csv(results_path, index=False)

display(results_df)
print("Kaydedildi:", results_path)
# Out:
#                      experiment_id     model dataset  seq_len  label_len  \
# 0   B0_patchtst_etth1_336_dm128_h4  PatchTST   ETTh1      336         48
# 1  B1_patchtst_etth1_512_dm128_h16  PatchTST   ETTh1      512         48
#
#    pred_len  d_model  d_ff  n_heads  e_layers  batch_size  max_epochs  \
# 0        96      128   256        4         3          32          10
# 1        96      128   256       16         3          32          20
#
#    best_epoch  patience  learning_rate  best_val_loss  test_mse  test_mae  \
# 0           7         3         0.0001       0.673162  0.373876  0.398880
# 1           6         5         0.0001       0.738233  0.376424  0.405316
#
#       status
# 0  completed
# 1  completed
# Kaydedildi: /content/drive/MyDrive/BIL401_Regime_Head_Pruning/results/baseline_experiments.csv

# %%
CONFIG_DIR = PROJECT_DIR / "configs"
CONFIG_DIR.mkdir(parents=True, exist_ok=True)

b1_config = """
experiment_id: B1_patchtst_etth1_512_dm128_h16

model:
  name: PatchTST
  d_model: 128
  d_ff: 256
  n_heads: 16
  e_layers: 3
  d_layers: 1
  factor: 3
  dropout: 0.1

data:
  name: ETTh1
  root_path: ./dataset/ETDataset/ETT-small/
  data_path: ETTh1.csv
  features: M
  target: OT
  freq: h
  seq_len: 512
  label_len: 48
  pred_len: 96
  enc_in: 7
  dec_in: 7
  c_out: 7

training:
  batch_size: 32
  max_epochs: 20
  best_epoch: 6
  patience: 5
  learning_rate: 0.0001
  loss: MSE
  lradj: type1
  optimizer: Adam
  use_gpu: true

results:
  best_val_loss: 0.7382330
  test_mse: 0.37642401456832886
  test_mae: 0.40531596541404724

notes:
  description: baseline_b1
  checkpoint_selected_by: validation_loss
""".strip()

config_path = (
    CONFIG_DIR
    / "B1_patchtst_etth1_512_dm128_h16.yaml"
)

config_path.write_text(
    b1_config,
    encoding="utf-8",
)

print("Config kaydedildi:")
print(config_path)
# Out:
# Config kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/configs/B1_patchtst_etth1_512_dm128_h16.yaml

# %%
from pathlib import Path

checkpoint_root = Path(
    "/content/Time-Series-Library/checkpoints"
)

b1_matches = [
    path
    for path in checkpoint_root.iterdir()
    if "ETTh1_512_96_dm128_h16" in path.name
]

print("Bulunan B1 checkpoint klasörleri:")

for path in b1_matches:
    print(path)
# Out:
# Bulunan B1 checkpoint klasörleri:
# /content/Time-Series-Library/checkpoints/long_term_forecast_ETTh1_512_96_dm128_h16_PatchTST_ETTh1_ftM_sl512_ll48_pl96_dm128_nh16_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b1_0

# %%
import shutil

CHECKPOINT_DIR = PROJECT_DIR / "checkpoints"
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)

if len(b1_matches) != 1:
    raise RuntimeError(
        f"1 B1 checkpoint bekleniyordu, {len(b1_matches)} bulundu."
    )

source_b1 = b1_matches[0]

target_b1 = (
    CHECKPOINT_DIR
    / "B1_patchtst_etth1_512_dm128_h16"
)

if target_b1.exists():
    shutil.rmtree(target_b1)

shutil.copytree(
    source_b1,
    target_b1,
)

print("B1 checkpoint kaydedildi:")
print(target_b1)

print("CSV:")
display(pd.read_csv(results_path))

print("\nConfig:")
print(config_path.read_text(encoding="utf-8"))

print("\nCheckpoint dosyaları:")
for path in target_b1.rglob("*"):
    print(path)
# Out:
# B1 checkpoint kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/checkpoints/B1_patchtst_etth1_512_dm128_h16
# CSV:
#                      experiment_id     model dataset  seq_len  label_len  \
# 0   B0_patchtst_etth1_336_dm128_h4  PatchTST   ETTh1      336         48
# 1  B1_patchtst_etth1_512_dm128_h16  PatchTST   ETTh1      512         48
#
#    pred_len  d_model  d_ff  n_heads  e_layers  batch_size  max_epochs  \
# 0        96      128   256        4         3          32          10
# 1        96      128   256       16         3          32          20
#
#    best_epoch  patience  learning_rate  best_val_loss  test_mse  test_mae  \
# 0           7         3         0.0001       0.673162  0.373876  0.398880
# 1           6         5         0.0001       0.738233  0.376424  0.405316
#
#       status
# 0  completed
# 1  completed
# Config:
# experiment_id: B1_patchtst_etth1_512_dm128_h16
#
# model:
#   name: PatchTST
#   d_model: 128
#   d_ff: 256
#   n_heads: 16
#   e_layers: 3
#   d_layers: 1
#   factor: 3
#   dropout: 0.1
#
# data:
#   name: ETTh1
#   root_path: ./dataset/ETDataset/ETT-small/
#   data_path: ETTh1.csv
#   features: M
#   target: OT
#   freq: h
#   seq_len: 512
#   label_len: 48
#   pred_len: 96
#   enc_in: 7
#   dec_in: 7
#   c_out: 7
#
# training:
#   batch_size: 32
#   max_epochs: 20
#   best_epoch: 6
#   patience: 5
#   learning_rate: 0.0001
#   loss: MSE
#   lradj: type1
#   optimizer: Adam
#   use_gpu: true
#
# results:
#   best_val_loss: 0.7382330
#   test_mse: 0.37642401456832886
#   test_mae: 0.40531596541404724
#
# notes:
#   description: baseline_b1
#   checkpoint_selected_by: validation_loss
#
# Checkpoint dosyaları:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/checkpoints/B1_patchtst_etth1_512_dm128_h16/checkpoint.pth

# %%
# %cd /content/Time-Series-Library

# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/ETDataset/ETT-small/ \
  --data_path ETTh1.csv \
  --model_id ETTh1_512_96_dm256_h16 \
  --model PatchTST \
  --data ETTh1 \
  --features M \
  --seq_len 512 \
  --label_len 48 \
  --pred_len 96 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --e_layers 3 \
  --d_layers 1 \
  --factor 3 \
  --d_model 256 \
  --d_ff 512 \
  --n_heads 16 \
  --batch_size 32 \
  --train_epochs 20 \
  --patience 5 \
  --learning_rate 0.0001 \
  --des baseline_b2 \
  --itr 1
# Out:
# /content/Time-Series-Library
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh1_512_96_dm256_h16Model:              PatchTST
#
# Data Loader
#   Data:               ETTh1               Root Path:          ./dataset/ETDataset/ETT-small/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            512                 Label Len:          48
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            256
#   n heads:            16                  e layers:           3
#   d layers:           1                   d FF:               512
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       20                  Batch Size:         32
#   Patience:           5                   Learning Rate:      0.0001
#   Des:                baseline_b2         Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: PatchTST ...
# >>>>>>>start training : long_term_forecast_ETTh1_512_96_dm256_h16_PatchTST_ETTh1_ftM_sl512_ll48_pl96_dm256_nh16_el3_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b2_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8033
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.3785275
# 	speed: 0.1527s/iter; left time: 754.7003s
# 	iters: 200, epoch: 1 | loss: 0.3352827
# 	speed: 0.0811s/iter; left time: 392.3855s
# Epoch: 1 cost time: 22.202448844909668
# Epoch: 1, Steps: 252 | Train Loss: 0.4296095 Vali Loss: 0.8658466 Test Loss: 0.4107741
# Validation loss decreased (inf --> 0.865847).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3463824
# 	speed: 0.1835s/iter; left time: 860.5933s
# 	iters: 200, epoch: 2 | loss: 0.3588050
# 	speed: 0.0832s/iter; left time: 381.9850s
# Epoch: 2 cost time: 21.20303177833557
# Epoch: 2, Steps: 252 | Train Loss: 0.3782864 Vali Loss: 0.8354515 Test Loss: 0.4242905
# Validation loss decreased (0.865847 --> 0.835451).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.3899933
# 	speed: 0.1892s/iter; left time: 839.6177s
# 	iters: 200, epoch: 3 | loss: 0.3101950
# 	speed: 0.0861s/iter; left time: 373.5882s
# Epoch: 3 cost time: 21.95957636833191
# Epoch: 3, Steps: 252 | Train Loss: 0.3459773 Vali Loss: 0.7827365 Test Loss: 0.3937002
# Validation loss decreased (0.835451 --> 0.782736).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.3171377
# 	speed: 0.1976s/iter; left time: 826.8106s
# 	iters: 200, epoch: 4 | loss: 0.3307526
# 	speed: 0.0901s/iter; left time: 367.9748s
# Epoch: 4 cost time: 23.03962779045105
# Epoch: 4, Steps: 252 | Train Loss: 0.3295933 Vali Loss: 0.7859426 Test Loss: 0.3972968
# EarlyStopping counter: 1 out of 5
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.3761413
# 	speed: 0.2091s/iter; left time: 822.2750s
# 	iters: 200, epoch: 5 | loss: 0.2991844
# 	speed: 0.0917s/iter; left time: 351.4046s
# Epoch: 5 cost time: 23.642621994018555
# Epoch: 5, Steps: 252 | Train Loss: 0.3232761 Vali Loss: 0.7811291 Test Loss: 0.3956731
# Validation loss decreased (0.782736 --> 0.781129).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.3035583
# 	speed: 0.1991s/iter; left time: 732.9200s
# 	iters: 200, epoch: 6 | loss: 0.3373869
# 	speed: 0.0885s/iter; left time: 316.7577s
# Epoch: 6 cost time: 22.596667051315308
# Epoch: 6, Steps: 252 | Train Loss: 0.3179185 Vali Loss: 0.7846245 Test Loss: 0.3945687
# EarlyStopping counter: 1 out of 5
# Updating learning rate to 3.125e-06
# 	iters: 100, epoch: 7 | loss: 0.3436530
# 	speed: 0.2004s/iter; left time: 687.0322s
# 	iters: 200, epoch: 7 | loss: 0.3562682
# 	speed: 0.0911s/iter; left time: 303.3278s
# Epoch: 7 cost time: 23.130271911621094
# Epoch: 7, Steps: 252 | Train Loss: 0.3157276 Vali Loss: 0.7813542 Test Loss: 0.3993161
# EarlyStopping counter: 2 out of 5
# Updating learning rate to 1.5625e-06
# 	iters: 100, epoch: 8 | loss: 0.3161365
# 	speed: 0.2057s/iter; left time: 653.4185s
# 	iters: 200, epoch: 8 | loss: 0.3757542
# 	speed: 0.0903s/iter; left time: 277.8637s
# Epoch: 8 cost time: 23.14505672454834
# Epoch: 8, Steps: 252 | Train Loss: 0.3151220 Vali Loss: 0.7930388 Test Loss: 0.3986729
# EarlyStopping counter: 3 out of 5
# Updating learning rate to 7.8125e-07
# 	iters: 100, epoch: 9 | loss: 0.3187765
# 	speed: 0.2012s/iter; left time: 588.5818s
# 	iters: 200, epoch: 9 | loss: 0.3652543
# 	speed: 0.0893s/iter; left time: 252.3999s
# Epoch: 9 cost time: 22.79055881500244
# Epoch: 9, Steps: 252 | Train Loss: 0.3139420 Vali Loss: 0.7816318 Test Loss: 0.4003181
# EarlyStopping counter: 4 out of 5
# Updating learning rate to 3.90625e-07
# 	iters: 100, epoch: 10 | loss: 0.2989124
# 	speed: 0.1995s/iter; left time: 533.2449s
# 	iters: 200, epoch: 10 | loss: 0.3176336
# 	speed: 0.0908s/iter; left time: 233.7073s
# Epoch: 10 cost time: 23.114843606948853
# Epoch: 10, Steps: 252 | Train Loss: 0.3142604 Vali Loss: 0.7869027 Test Loss: 0.3978760
# EarlyStopping counter: 5 out of 5
# Early stopping
# >>>>>>>testing : long_term_forecast_ETTh1_512_96_dm256_h16_PatchTST_ETTh1_ftM_sl512_ll48_pl96_dm256_nh16_el3_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b2_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (2785, 96, 7) (2785, 96, 7)
# test shape: (2785, 96, 7) (2785, 96, 7)
# mse:0.39473891258239746, mae:0.4233819246292114, dtw:Not calculated

# %%
import pandas as pd
from pathlib import Path

PROJECT_DIR = Path(
    "/content/drive/MyDrive/BIL401_Regime_Head_Pruning"
)

RESULT_DIR = PROJECT_DIR / "results"
RESULT_DIR.mkdir(parents=True, exist_ok=True)

results_path = RESULT_DIR / "baseline_experiments.csv"

b2_result = {
    "experiment_id": "B2_patchtst_etth1_512_dm256_h16",
    "model": "PatchTST",
    "dataset": "ETTh1",
    "seq_len": 512,
    "label_len": 48,
    "pred_len": 96,
    "d_model": 256,
    "d_ff": 512,
    "n_heads": 16,
    "e_layers": 3,
    "batch_size": 32,
    "max_epochs": 20,
    "best_epoch": 5,
    "patience": 5,
    "learning_rate": 0.0001,
    "best_val_loss": 0.7811291,
    "test_mse": 0.39473891258239746,
    "test_mae": 0.4233819246292114,
    "status": "completed",
    "rerun_confirmed": True,
}

if results_path.exists():
    results_df = pd.read_csv(results_path)
else:
    results_df = pd.DataFrame()

results_df = pd.concat(
    [results_df, pd.DataFrame([b2_result])],
    ignore_index=True,
)

results_df = results_df.drop_duplicates(
    subset=["experiment_id"],
    keep="last",
)

results_df.to_csv(results_path, index=False)

display(results_df)
print("B2 sonucu kaydedildi:")
print(results_path)
# Out:
#                      experiment_id     model dataset  seq_len  label_len  \
# 0  B2_patchtst_etth1_512_dm256_h16  PatchTST   ETTh1      512         48
#
#    pred_len  d_model  d_ff  n_heads  e_layers  batch_size  max_epochs  \
# 0        96      256   512       16         3          32          20
#
#    best_epoch  patience  learning_rate  best_val_loss  test_mse  test_mae  \
# 0           5         5         0.0001       0.781129  0.394739  0.423382
#
#       status  rerun_confirmed
# 0  completed             True
# B2 sonucu kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/results/baseline_experiments.csv

# %%
CONFIG_DIR = PROJECT_DIR / "configs"
CONFIG_DIR.mkdir(parents=True, exist_ok=True)

b2_config = """
experiment_id: B2_patchtst_etth1_512_dm256_h16

model:
  name: PatchTST
  d_model: 256
  d_ff: 512
  n_heads: 16
  e_layers: 3
  d_layers: 1
  factor: 3
  dropout: 0.1

data:
  name: ETTh1
  root_path: ./dataset/ETDataset/ETT-small/
  data_path: ETTh1.csv
  features: M
  target: OT
  freq: h
  seq_len: 512
  label_len: 48
  pred_len: 96
  enc_in: 7
  dec_in: 7
  c_out: 7

training:
  batch_size: 32
  max_epochs: 20
  best_epoch: 5
  patience: 5
  learning_rate: 0.0001
  loss: MSE
  lradj: type1
  optimizer: Adam
  use_gpu: true

results:
  best_val_loss: 0.7811291
  test_mse: 0.39473891258239746
  test_mae: 0.4233819246292114

reproducibility:
  rerun_completed: true
  rerun_result_identical: true

notes:
  description: baseline_b2
  checkpoint_selected_by: validation_loss
""".strip()

b2_config_path = (
    CONFIG_DIR
    / "B2_patchtst_etth1_512_dm256_h16.yaml"
)

b2_config_path.write_text(
    b2_config,
    encoding="utf-8",
)

print("B2 config kaydedildi:")
print(b2_config_path)
# Out:
# B2 config kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/configs/B2_patchtst_etth1_512_dm256_h16.yaml

# %%
from pathlib import Path

checkpoint_root = Path(
    "/content/Time-Series-Library/checkpoints"
)

b2_matches = [
    path
    for path in checkpoint_root.iterdir()
    if "ETTh1_512_96_dm256_h16" in path.name
]

print("Bulunan B2 checkpoint klasörleri:")

for path in b2_matches:
    print(path)
# Out:
# Bulunan B2 checkpoint klasörleri:
# /content/Time-Series-Library/checkpoints/long_term_forecast_ETTh1_512_96_dm256_h16_PatchTST_ETTh1_ftM_sl512_ll48_pl96_dm256_nh16_el3_dl1_df512_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b2_0

# %%
import shutil

CHECKPOINT_DIR = PROJECT_DIR / "checkpoints"
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)

if len(b2_matches) != 1:
    raise RuntimeError(
        f"1 B2 checkpoint bekleniyordu, {len(b2_matches)} bulundu."
    )

source_b2 = b2_matches[0]

target_b2 = (
    CHECKPOINT_DIR
    / "B2_patchtst_etth1_512_dm256_h16"
)

if target_b2.exists():
    shutil.rmtree(target_b2)

shutil.copytree(
    source_b2,
    target_b2,
)

print("B2 checkpoint yeniden kaydedildi:")
print(target_b2)
# Out:
# B2 checkpoint yeniden kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/checkpoints/B2_patchtst_etth1_512_dm256_h16

# %%
print("CSV:")
display(pd.read_csv(results_path))

print("\nConfig:")
print(b2_config_path.read_text(encoding="utf-8"))

print("\nCheckpoint dosyaları:")
for path in target_b2.rglob("*"):
    print(path)
# Out:
# CSV:
#                      experiment_id     model dataset  seq_len  label_len  \
# 0  B2_patchtst_etth1_512_dm256_h16  PatchTST   ETTh1      512         48
#
#    pred_len  d_model  d_ff  n_heads  e_layers  batch_size  max_epochs  \
# 0        96      256   512       16         3          32          20
#
#    best_epoch  patience  learning_rate  best_val_loss  test_mse  test_mae  \
# 0           5         5         0.0001       0.781129  0.394739  0.423382
#
#       status  rerun_confirmed
# 0  completed             True
# Config:
# experiment_id: B2_patchtst_etth1_512_dm256_h16
#
# model:
#   name: PatchTST
#   d_model: 256
#   d_ff: 512
#   n_heads: 16
#   e_layers: 3
#   d_layers: 1
#   factor: 3
#   dropout: 0.1
#
# data:
#   name: ETTh1
#   root_path: ./dataset/ETDataset/ETT-small/
#   data_path: ETTh1.csv
#   features: M
#   target: OT
#   freq: h
#   seq_len: 512
#   label_len: 48
#   pred_len: 96
#   enc_in: 7
#   dec_in: 7
#   c_out: 7
#
# training:
#   batch_size: 32
#   max_epochs: 20
#   best_epoch: 5
#   patience: 5
#   learning_rate: 0.0001
#   loss: MSE
#   lradj: type1
#   optimizer: Adam
#   use_gpu: true
#
# results:
#   best_val_loss: 0.7811291
#   test_mse: 0.39473891258239746
#   test_mae: 0.4233819246292114
#
# reproducibility:
#   rerun_completed: true
#   rerun_result_identical: true
#
# notes:
#   description: baseline_b2
#   checkpoint_selected_by: validation_loss
#
# Checkpoint dosyaları:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/checkpoints/B2_patchtst_etth1_512_dm256_h16/checkpoint.pth

# %%
results_df = pd.read_csv(results_path)

comparison_columns = [
    "experiment_id",
    "seq_len",
    "d_model",
    "d_ff",
    "n_heads",
    "best_epoch",
    "best_val_loss",
    "test_mse",
    "test_mae",
]

comparison_df = (
    results_df[comparison_columns]
    .sort_values("best_val_loss")
    .reset_index(drop=True)
)

display(comparison_df)
# Out:
#                      experiment_id  seq_len  d_model  d_ff  n_heads  \
# 0  B2_patchtst_etth1_512_dm256_h16      512      256   512       16
#
#    best_epoch  best_val_loss  test_mse  test_mae
# 0           5       0.781129  0.394739  0.423382

# %%
# %cd /content/Time-Series-Library

# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/ETDataset/ETT-small/ \
  --data_path ETTh1.csv \
  --model_id ETTh1_336_96_dm128_h16 \
  --model PatchTST \
  --data ETTh1 \
  --features M \
  --seq_len 336 \
  --label_len 48 \
  --pred_len 96 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --e_layers 3 \
  --d_layers 1 \
  --factor 3 \
  --d_model 128 \
  --d_ff 256 \
  --n_heads 16 \
  --batch_size 32 \
  --train_epochs 10 \
  --patience 3 \
  --learning_rate 0.0001 \
  --des baseline_b3 \
  --itr 1
# Out:
# /content/Time-Series-Library
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh1_336_96_dm128_h16Model:              PatchTST
#
# Data Loader
#   Data:               ETTh1               Root Path:          ./dataset/ETDataset/ETT-small/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            336                 Label Len:          48
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            128
#   n heads:            16                  e layers:           3
#   d layers:           1                   d FF:               256
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       10                  Batch Size:         32
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                baseline_b3         Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: PatchTST ...
# >>>>>>>start training : long_term_forecast_ETTh1_336_96_dm128_h16_PatchTST_ETTh1_ftM_sl336_ll48_pl96_dm128_nh16_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b3_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.4276939
# 	speed: 0.0478s/iter; left time: 118.1468s
# 	iters: 200, epoch: 1 | loss: 0.4185023
# 	speed: 0.0284s/iter; left time: 67.2478s
# Epoch: 1 cost time: 8.132698774337769
# Epoch: 1, Steps: 257 | Train Loss: 0.4220656 Vali Loss: 0.7299377 Test Loss: 0.3967650
# Validation loss decreased (inf --> 0.729938).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3907284
# 	speed: 0.0803s/iter; left time: 177.7608s
# 	iters: 200, epoch: 2 | loss: 0.3480385
# 	speed: 0.0288s/iter; left time: 60.7921s
# Epoch: 2 cost time: 7.7863733768463135
# Epoch: 2, Steps: 257 | Train Loss: 0.3810270 Vali Loss: 0.7184745 Test Loss: 0.3925545
# Validation loss decreased (0.729938 --> 0.718474).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.3873662
# 	speed: 0.0822s/iter; left time: 160.8711s
# 	iters: 200, epoch: 3 | loss: 0.3709745
# 	speed: 0.0293s/iter; left time: 54.3851s
# Epoch: 3 cost time: 8.026969194412231
# Epoch: 3, Steps: 257 | Train Loss: 0.3639234 Vali Loss: 0.6930032 Test Loss: 0.3786595
# Validation loss decreased (0.718474 --> 0.693003).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.3147117
# 	speed: 0.0810s/iter; left time: 137.6927s
# 	iters: 200, epoch: 4 | loss: 0.3323154
# 	speed: 0.0296s/iter; left time: 47.3264s
# Epoch: 4 cost time: 8.124433755874634
# Epoch: 4, Steps: 257 | Train Loss: 0.3565894 Vali Loss: 0.6831741 Test Loss: 0.3768752
# Validation loss decreased (0.693003 --> 0.683174).  Saving model ...
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.2950712
# 	speed: 0.0784s/iter; left time: 113.1322s
# 	iters: 200, epoch: 5 | loss: 0.2984290
# 	speed: 0.0302s/iter; left time: 40.5114s
# Epoch: 5 cost time: 8.096556425094604
# Epoch: 5, Steps: 257 | Train Loss: 0.3522292 Vali Loss: 0.6838592 Test Loss: 0.3757403
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.3252157
# 	speed: 0.0793s/iter; left time: 94.0431s
# 	iters: 200, epoch: 6 | loss: 0.4564814
# 	speed: 0.0311s/iter; left time: 33.7292s
# Epoch: 6 cost time: 8.247287273406982
# Epoch: 6, Steps: 257 | Train Loss: 0.3504660 Vali Loss: 0.6830628 Test Loss: 0.3750410
# Validation loss decreased (0.683174 --> 0.683063).  Saving model ...
# Updating learning rate to 3.125e-06
# 	iters: 100, epoch: 7 | loss: 0.3727168
# 	speed: 0.0809s/iter; left time: 75.1520s
# 	iters: 200, epoch: 7 | loss: 0.3530122
# 	speed: 0.0313s/iter; left time: 25.9631s
# Epoch: 7 cost time: 8.348770380020142
# Epoch: 7, Steps: 257 | Train Loss: 0.3492684 Vali Loss: 0.6781806 Test Loss: 0.3745288
# Validation loss decreased (0.683063 --> 0.678181).  Saving model ...
# Updating learning rate to 1.5625e-06
# 	iters: 100, epoch: 8 | loss: 0.3417110
# 	speed: 0.0817s/iter; left time: 54.9249s
# 	iters: 200, epoch: 8 | loss: 0.3162542
# 	speed: 0.0314s/iter; left time: 17.9433s
# Epoch: 8 cost time: 8.47352147102356
# Epoch: 8, Steps: 257 | Train Loss: 0.3488082 Vali Loss: 0.6780880 Test Loss: 0.3743904
# Validation loss decreased (0.678181 --> 0.678088).  Saving model ...
# Updating learning rate to 7.8125e-07
# 	iters: 100, epoch: 9 | loss: 0.3032313
# 	speed: 0.0825s/iter; left time: 34.2321s
# 	iters: 200, epoch: 9 | loss: 0.3666785
# 	speed: 0.0306s/iter; left time: 9.6293s
# Epoch: 9 cost time: 8.27940559387207
# Epoch: 9, Steps: 257 | Train Loss: 0.3482319 Vali Loss: 0.6816983 Test Loss: 0.3743587
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 3.90625e-07
# 	iters: 100, epoch: 10 | loss: 0.3368394
# 	speed: 0.0838s/iter; left time: 13.2450s
# 	iters: 200, epoch: 10 | loss: 0.3555582
# 	speed: 0.0303s/iter; left time: 1.7588s
# Epoch: 10 cost time: 8.154093742370605
# Epoch: 10, Steps: 257 | Train Loss: 0.3488119 Vali Loss: 0.6874044 Test Loss: 0.3744267
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 1.953125e-07
# >>>>>>>testing : long_term_forecast_ETTh1_336_96_dm128_h16_PatchTST_ETTh1_ftM_sl336_ll48_pl96_dm128_nh16_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b3_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (2785, 96, 7) (2785, 96, 7)
# test shape: (2785, 96, 7) (2785, 96, 7)
# mse:0.3735102415084839, mae:0.39940717816352844, dtw:Not calculated

# %%
import pandas as pd
from pathlib import Path

PROJECT_DIR = Path(
    "/content/drive/MyDrive/BIL401_Regime_Head_Pruning"
)

RESULT_DIR = PROJECT_DIR / "results"
RESULT_DIR.mkdir(parents=True, exist_ok=True)

results_path = RESULT_DIR / "baseline_experiments.csv"

b3_result = {
    "experiment_id": "B3_patchtst_etth1_336_dm128_h16",
    "model": "PatchTST",
    "dataset": "ETTh1",
    "seq_len": 336,
    "label_len": 48,
    "pred_len": 96,
    "d_model": 128,
    "d_ff": 256,
    "n_heads": 16,
    "e_layers": 3,
    "batch_size": 32,
    "max_epochs": 10,
    "best_epoch": 8,
    "patience": 3,
    "learning_rate": 0.0001,
    "best_val_loss": 0.6780880,
    "test_mse": 0.3735102415084839,
    "test_mae": 0.39940717816352844,
    "status": "completed",
}

if results_path.exists():
    results_df = pd.read_csv(results_path)
else:
    results_df = pd.DataFrame()

results_df = pd.concat(
    [results_df, pd.DataFrame([b3_result])],
    ignore_index=True,
)

results_df = results_df.drop_duplicates(
    subset=["experiment_id"],
    keep="last",
)

results_df.to_csv(results_path, index=False)

display(results_df)
print("B3 sonucu kaydedildi:")
print(results_path)
# Out:
#                      experiment_id     model dataset  seq_len  label_len  \
# 0  B2_patchtst_etth1_512_dm256_h16  PatchTST   ETTh1      512         48
# 1  B3_patchtst_etth1_336_dm128_h16  PatchTST   ETTh1      336         48
#
#    pred_len  d_model  d_ff  n_heads  e_layers  batch_size  max_epochs  \
# 0        96      256   512       16         3          32          20
# 1        96      128   256       16         3          32          10
#
#    best_epoch  patience  learning_rate  best_val_loss  test_mse  test_mae  \
# 0           5         5         0.0001       0.781129  0.394739  0.423382
# 1           8         3         0.0001       0.678088  0.373510  0.399407
#
#       status rerun_confirmed
# 0  completed            True
# 1  completed             NaN
# B3 sonucu kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/results/baseline_experiments.csv

# %%
CONFIG_DIR = PROJECT_DIR / "configs"
CONFIG_DIR.mkdir(parents=True, exist_ok=True)

b3_config = """
experiment_id: B3_patchtst_etth1_336_dm128_h16

model:
  name: PatchTST
  d_model: 128
  d_ff: 256
  n_heads: 16
  e_layers: 3
  d_layers: 1
  factor: 3
  dropout: 0.1

data:
  name: ETTh1
  root_path: ./dataset/ETDataset/ETT-small/
  data_path: ETTh1.csv
  features: M
  target: OT
  freq: h
  seq_len: 336
  label_len: 48
  pred_len: 96
  enc_in: 7
  dec_in: 7
  c_out: 7

training:
  batch_size: 32
  max_epochs: 10
  best_epoch: 8
  patience: 3
  learning_rate: 0.0001
  loss: MSE
  lradj: type1
  optimizer: Adam
  use_gpu: true

results:
  best_val_loss: 0.6780880
  test_mse: 0.3735102415084839
  test_mae: 0.39940717816352844

notes:
  description: baseline_b3
  checkpoint_selected_by: validation_loss
""".strip()

b3_config_path = (
    CONFIG_DIR
    / "B3_patchtst_etth1_336_dm128_h16.yaml"
)

b3_config_path.write_text(
    b3_config,
    encoding="utf-8",
)

print("B3 config kaydedildi:")
print(b3_config_path)
# Out:
# B3 config kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/configs/B3_patchtst_etth1_336_dm128_h16.yaml

# %%
from pathlib import Path

checkpoint_root = Path(
    "/content/Time-Series-Library/checkpoints"
)

b3_matches = [
    path
    for path in checkpoint_root.iterdir()
    if "ETTh1_336_96_dm128_h16" in path.name
]

for path in b3_matches:
    print(path)
# Out:
# /content/Time-Series-Library/checkpoints/long_term_forecast_ETTh1_336_96_dm128_h16_PatchTST_ETTh1_ftM_sl336_ll48_pl96_dm128_nh16_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b3_0

# %%
import shutil

CHECKPOINT_DIR = PROJECT_DIR / "checkpoints"
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)

if len(b3_matches) != 1:
    raise RuntimeError(
        f"1 B3 checkpoint bekleniyordu, {len(b3_matches)} bulundu."
    )

source_b3 = b3_matches[0]

target_b3 = (
    CHECKPOINT_DIR
    / "B3_patchtst_etth1_336_dm128_h16"
)

if target_b3.exists():
    shutil.rmtree(target_b3)

shutil.copytree(
    source_b3,
    target_b3,
)

print("B3 checkpoint kaydedildi:")
print(target_b3)
# Out:
# B3 checkpoint kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/checkpoints/B3_patchtst_etth1_336_dm128_h16

# %%
# %cd /content/Time-Series-Library

# !python -u run.py \
  --task_name long_term_forecast \
  --is_training 1 \
  --root_path ./dataset/ETDataset/ETT-small/ \
  --data_path ETTh1.csv \
  --model_id ETTh1_336_96_dm128_h8 \
  --model PatchTST \
  --data ETTh1 \
  --features M \
  --seq_len 336 \
  --label_len 48 \
  --pred_len 96 \
  --enc_in 7 \
  --dec_in 7 \
  --c_out 7 \
  --e_layers 3 \
  --d_layers 1 \
  --factor 3 \
  --d_model 128 \
  --d_ff 256 \
  --n_heads 8 \
  --batch_size 32 \
  --train_epochs 10 \
  --patience 3 \
  --learning_rate 0.0001 \
  --des baseline_b4 \
  --itr 1
# Out:
# /content/Time-Series-Library
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           ETTh1_336_96_dm128_h8Model:              PatchTST
#
# Data Loader
#   Data:               ETTh1               Root Path:          ./dataset/ETDataset/ETT-small/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            336                 Label Len:          48
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             7                   Dec In:             7
#   C Out:              7                   d model:            128
#   n heads:            8                   e layers:           3
#   d layers:           1                   d FF:               256
#   Moving Avg:         25                  Factor:             3
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        10                  Itr:                1
#   Train Epochs:       10                  Batch Size:         32
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                baseline_b4         Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 🚀 Lazy Loading: PatchTST ...
# >>>>>>>start training : long_term_forecast_ETTh1_336_96_dm128_h8_PatchTST_ETTh1_ftM_sl336_ll48_pl96_dm128_nh8_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b4_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8209
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.4295151
# 	speed: 0.0411s/iter; left time: 101.6689s
# 	iters: 200, epoch: 1 | loss: 0.4154102
# 	speed: 0.0232s/iter; left time: 55.0923s
# Epoch: 1 cost time: 6.745072364807129
# Epoch: 1, Steps: 257 | Train Loss: 0.4217984 Vali Loss: 0.7306947 Test Loss: 0.3969414
# Validation loss decreased (inf --> 0.730695).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.3963138
# 	speed: 0.0724s/iter; left time: 160.3070s
# 	iters: 200, epoch: 2 | loss: 0.3520745
# 	speed: 0.0236s/iter; left time: 49.8376s
# Epoch: 2 cost time: 6.57606053352356
# Epoch: 2, Steps: 257 | Train Loss: 0.3805242 Vali Loss: 0.7182834 Test Loss: 0.3928833
# Validation loss decreased (0.730695 --> 0.718283).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.3821889
# 	speed: 0.0692s/iter; left time: 135.3297s
# 	iters: 200, epoch: 3 | loss: 0.3708694
# 	speed: 0.0247s/iter; left time: 45.8782s
# Epoch: 3 cost time: 6.879234790802002
# Epoch: 3, Steps: 257 | Train Loss: 0.3634309 Vali Loss: 0.6893346 Test Loss: 0.3774374
# Validation loss decreased (0.718283 --> 0.689335).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.3210790
# 	speed: 0.0675s/iter; left time: 114.7067s
# 	iters: 200, epoch: 4 | loss: 0.3340530
# 	speed: 0.0243s/iter; left time: 38.8615s
# Epoch: 4 cost time: 6.715041875839233
# Epoch: 4, Steps: 257 | Train Loss: 0.3559083 Vali Loss: 0.6806074 Test Loss: 0.3761475
# Validation loss decreased (0.689335 --> 0.680607).  Saving model ...
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.3045839
# 	speed: 0.0715s/iter; left time: 103.2061s
# 	iters: 200, epoch: 5 | loss: 0.2985112
# 	speed: 0.0244s/iter; left time: 32.7687s
# Epoch: 5 cost time: 6.736758708953857
# Epoch: 5, Steps: 257 | Train Loss: 0.3518852 Vali Loss: 0.6804417 Test Loss: 0.3747753
# Validation loss decreased (0.680607 --> 0.680442).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.3237852
# 	speed: 0.0737s/iter; left time: 87.4519s
# 	iters: 200, epoch: 6 | loss: 0.4562311
# 	speed: 0.0248s/iter; left time: 26.9716s
# Epoch: 6 cost time: 6.921184062957764
# Epoch: 6, Steps: 257 | Train Loss: 0.3496000 Vali Loss: 0.6792158 Test Loss: 0.3738758
# Validation loss decreased (0.680442 --> 0.679216).  Saving model ...
# Updating learning rate to 3.125e-06
# 	iters: 100, epoch: 7 | loss: 0.3683666
# 	speed: 0.0690s/iter; left time: 64.0899s
# 	iters: 200, epoch: 7 | loss: 0.3494894
# 	speed: 0.0257s/iter; left time: 21.3228s
# Epoch: 7 cost time: 6.89879584312439
# Epoch: 7, Steps: 257 | Train Loss: 0.3486772 Vali Loss: 0.6734824 Test Loss: 0.3734598
# Validation loss decreased (0.679216 --> 0.673482).  Saving model ...
# Updating learning rate to 1.5625e-06
# 	iters: 100, epoch: 8 | loss: 0.3455576
# 	speed: 0.0694s/iter; left time: 46.6341s
# 	iters: 200, epoch: 8 | loss: 0.3186553
# 	speed: 0.0256s/iter; left time: 14.6428s
# Epoch: 8 cost time: 7.005062818527222
# Epoch: 8, Steps: 257 | Train Loss: 0.3485325 Vali Loss: 0.6738191 Test Loss: 0.3733659
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 7.8125e-07
# 	iters: 100, epoch: 9 | loss: 0.3016818
# 	speed: 0.0719s/iter; left time: 29.8531s
# 	iters: 200, epoch: 9 | loss: 0.3622290
# 	speed: 0.0255s/iter; left time: 8.0296s
# Epoch: 9 cost time: 6.900893449783325
# Epoch: 9, Steps: 257 | Train Loss: 0.3479265 Vali Loss: 0.6778159 Test Loss: 0.3732253
# EarlyStopping counter: 2 out of 3
# Updating learning rate to 3.90625e-07
# 	iters: 100, epoch: 10 | loss: 0.3316293
# 	speed: 0.0749s/iter; left time: 11.8393s
# 	iters: 200, epoch: 10 | loss: 0.3526897
# 	speed: 0.0250s/iter; left time: 1.4519s
# Epoch: 10 cost time: 6.95724081993103
# Epoch: 10, Steps: 257 | Train Loss: 0.3481519 Vali Loss: 0.6827647 Test Loss: 0.3733862
# EarlyStopping counter: 3 out of 3
# Early stopping
# >>>>>>>testing : long_term_forecast_ETTh1_336_96_dm128_h8_PatchTST_ETTh1_ftM_sl336_ll48_pl96_dm128_nh8_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b4_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (2785, 96, 7) (2785, 96, 7)
# test shape: (2785, 96, 7) (2785, 96, 7)
# mse:0.37254568934440613, mae:0.3982141613960266, dtw:Not calculated

# %%
import pandas as pd
from pathlib import Path

PROJECT_DIR = Path(
    "/content/drive/MyDrive/BIL401_Regime_Head_Pruning"
)

RESULT_DIR = PROJECT_DIR / "results"
RESULT_DIR.mkdir(parents=True, exist_ok=True)

results_path = RESULT_DIR / "baseline_experiments.csv"

b4_result = {
    "experiment_id": "B4_patchtst_etth1_336_dm128_h8",
    "model": "PatchTST",
    "dataset": "ETTh1",
    "seq_len": 336,
    "label_len": 48,
    "pred_len": 96,
    "d_model": 128,
    "d_ff": 256,
    "n_heads": 8,
    "e_layers": 3,
    "batch_size": 32,
    "max_epochs": 10,
    "best_epoch": 7,
    "patience": 3,
    "learning_rate": 0.0001,
    "best_val_loss": 0.6734824,
    "test_mse": 0.37254568934440613,
    "test_mae": 0.3982141613960266,
    "status": "completed",
}

if results_path.exists():
    results_df = pd.read_csv(results_path)
else:
    results_df = pd.DataFrame()

results_df = pd.concat(
    [results_df, pd.DataFrame([b4_result])],
    ignore_index=True,
)

results_df = results_df.drop_duplicates(
    subset=["experiment_id"],
    keep="last",
)

results_df.to_csv(results_path, index=False)

display(results_df)
print("B4 sonucu kaydedildi:")
print(results_path)
# Out:
#                      experiment_id     model dataset  seq_len  label_len  \
# 0  B2_patchtst_etth1_512_dm256_h16  PatchTST   ETTh1      512         48
# 1  B3_patchtst_etth1_336_dm128_h16  PatchTST   ETTh1      336         48
# 2   B4_patchtst_etth1_336_dm128_h8  PatchTST   ETTh1      336         48
#
#    pred_len  d_model  d_ff  n_heads  e_layers  batch_size  max_epochs  \
# 0        96      256   512       16         3          32          20
# 1        96      128   256       16         3          32          10
# 2        96      128   256        8         3          32          10
#
#    best_epoch  patience  learning_rate  best_val_loss  test_mse  test_mae  \
# 0           5         5         0.0001       0.781129  0.394739  0.423382
# 1           8         3         0.0001       0.678088  0.373510  0.399407
# 2           7         3         0.0001       0.673482  0.372546  0.398214
#
#       status rerun_confirmed
# 0  completed            True
# 1  completed             NaN
# 2  completed             NaN
# B4 sonucu kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/results/baseline_experiments.csv

# %%
CONFIG_DIR = PROJECT_DIR / "configs"
CONFIG_DIR.mkdir(parents=True, exist_ok=True)

b4_config = """
experiment_id: B4_patchtst_etth1_336_dm128_h8

model:
  name: PatchTST
  d_model: 128
  d_ff: 256
  n_heads: 8
  e_layers: 3
  d_layers: 1
  factor: 3
  dropout: 0.1

data:
  name: ETTh1
  root_path: ./dataset/ETDataset/ETT-small/
  data_path: ETTh1.csv
  features: M
  target: OT
  freq: h
  seq_len: 336
  label_len: 48
  pred_len: 96
  enc_in: 7
  dec_in: 7
  c_out: 7

training:
  batch_size: 32
  max_epochs: 10
  best_epoch: 7
  patience: 3
  learning_rate: 0.0001
  loss: MSE
  lradj: type1
  optimizer: Adam
  use_gpu: true

results:
  best_val_loss: 0.6734824
  test_mse: 0.37254568934440613
  test_mae: 0.3982141613960266

notes:
  description: baseline_b4
  checkpoint_selected_by: validation_loss
""".strip()

b4_config_path = (
    CONFIG_DIR
    / "B4_patchtst_etth1_336_dm128_h8.yaml"
)

b4_config_path.write_text(
    b4_config,
    encoding="utf-8",
)

print("B4 config kaydedildi:")
print(b4_config_path)
# Out:
# B4 config kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/configs/B4_patchtst_etth1_336_dm128_h8.yaml

# %%
from pathlib import Path

checkpoint_root = Path(
    "/content/Time-Series-Library/checkpoints"
)

b4_matches = [
    path
    for path in checkpoint_root.iterdir()
    if "ETTh1_336_96_dm128_h8" in path.name
]

for path in b4_matches:
    print(path)
# Out:
# /content/Time-Series-Library/checkpoints/long_term_forecast_ETTh1_336_96_dm128_h8_PatchTST_ETTh1_ftM_sl336_ll48_pl96_dm128_nh8_el3_dl1_df256_expand2_dc4_fc3_ebtimeF_dtTrue_baseline_b4_0

# %%
import shutil

CHECKPOINT_DIR = PROJECT_DIR / "checkpoints"
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)

if len(b4_matches) != 1:
    raise RuntimeError(
        f"1 B4 checkpoint bekleniyordu, {len(b4_matches)} bulundu."
    )

source_b4 = b4_matches[0]

target_b4 = (
    CHECKPOINT_DIR
    / "B4_patchtst_etth1_336_dm128_h8"
)

if target_b4.exists():
    shutil.rmtree(target_b4)

shutil.copytree(
    source_b4,
    target_b4,
)

print("B4 checkpoint kaydedildi:")
print(target_b4)
# Out:
# B4 checkpoint kaydedildi:
# /content/drive/MyDrive/BIL401_Regime_Head_Pruning/checkpoints/B4_patchtst_etth1_336_dm128_h8

# %%
import pandas as pd
from pathlib import Path

PROJECT_DIR = Path(
    "/content/drive/MyDrive/BIL401_Regime_Head_Pruning"
)

results_path = PROJECT_DIR / "results" / "baseline_experiments.csv"

results_df = pd.read_csv(results_path)

results_df["selected_for_pruning"] = False

results_df.loc[
    results_df["experiment_id"]
    == "B4_patchtst_etth1_336_dm128_h8",
    "selected_for_pruning"
] = True

results_df.to_csv(results_path, index=False)

display(results_df)
# Out:
#                      experiment_id     model dataset  seq_len  label_len  \
# 0  B2_patchtst_etth1_512_dm256_h16  PatchTST   ETTh1      512         48
# 1  B3_patchtst_etth1_336_dm128_h16  PatchTST   ETTh1      336         48
# 2   B4_patchtst_etth1_336_dm128_h8  PatchTST   ETTh1      336         48
#
#    pred_len  d_model  d_ff  n_heads  e_layers  ...  max_epochs  best_epoch  \
# 0        96      256   512       16         3  ...          20           5
# 1        96      128   256       16         3  ...          10           8
# 2        96      128   256        8         3  ...          10           7
#
#    patience  learning_rate  best_val_loss  test_mse  test_mae     status  \
# 0         5         0.0001       0.781129  0.394739  0.423382  completed
# 1         3         0.0001       0.678088  0.373510  0.399407  completed
# 2         3         0.0001       0.673482  0.372546  0.398214  completed
#
#   rerun_confirmed selected_for_pruning
# 0            True                False
# 1             NaN                False
# 2             NaN                 True
#
# [3 rows x 21 columns]
